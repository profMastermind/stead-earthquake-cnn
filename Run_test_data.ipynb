# %%
import main

# %%
main.test_net()
# Out:
# /home/mastermind/stead-earthquake-cnn-cpu/data/base_dataset.py:12: DtypeWarning: Columns (7,11,13,14,15,18,19,20,21,22,24,25,26,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.information = pd.read_csv(self.config['train_csv_path'])
# ### Test loss = 0.49986564460394595, mean DEPTH error = 3.5317394733428955,                               mean DISTANCE error = 2.5670228004455566, mean MAGNITUDE error = 0.16830603778362274
